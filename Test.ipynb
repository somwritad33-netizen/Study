# %%
# %sql
SELECT timestamp, event_type, message, level, details
FROM event_log('3b1d9545-d865-441e-b4ec-3a4854f3eb8d')
--WHERE event_type IN ('flow_progress', 'update_progress')
ORDER BY timestamp DESC

# %%
# %sql
select * from study.default.test

# %%
# %sql
SELECT
  timestamp,
  event_type,
  details
FROM event_log(TABLE(dev_p2p.bronze.bronze_vendor))
ORDER BY timestamp DESC
LIMIT 20

# %%
# %sql
SELECT
  timestamp,
  event_type,
  details:autoloader_details AS autoloader_info,
  details:flow_progress AS flow_info
FROM event_log(TABLE(dev_p2p.bronze.bronze_vendor))
WHERE event_type IN ('flow_progress', 'planning_information')
ORDER BY timestamp DESC

# %%
# %sql
SELECT *
FROM event_log(TABLE(dev_p2p.bronze.bronze_vendor))
ORDER BY timestamp DESC

# %%
print(map(lambda x: x+1),'123')

# %%
# %sql
SELECT
  timestamp,
  event_type,
  details
FROM event_log(TABLE(dev_p2p.bronze.bronze_vendor))
ORDER BY timestamp DESC
LIMIT 20

# %%
# %sql
select * from  dev_p2p.bronze.bronze_gr_pdf1

# %%
# %sql
select * from  dev_p2p.bronze.bronze_invoice_pdf

# %%
# %sql
select * from  dev_p2p.bronze.bronze_po_pdf

# %%
# %sql
select * from  dev_p2p.bronze.bronze_gr_pdf
